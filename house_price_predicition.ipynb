# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\db\housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = data.drop(["median_house_value"],axis=1)
y = data["median_house_value"]

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12893    -121.33     38.65                23.0       2446.0           523.0
# 19585    -120.69     37.59                27.0       1170.0           227.0
# 9541     -120.74     37.33                30.0       2390.0           470.0
# 20375    -118.84     34.15                17.0       3785.0           494.0
# 19318    -123.02     38.46                52.0       2154.0           499.0
# ...          ...       ...                 ...          ...             ...
# 12820    -121.48     38.61                18.0       1511.0           315.0
# 954      -121.92     37.64                46.0       1280.0           209.0
# 4531     -118.21     34.04                43.0       1502.0           477.0
# 10390    -117.65     33.57                 5.0       1998.0           500.0
# 12304    -116.80     33.80                35.0        324.0            63.0
#
#        population  households  median_income ocean_proximity  \
# 12893      1132.0       513.0         2.6266          INLAND
# 19585       660.0       222.0         2.3906          INLAND
# 9541       1409.0       428.0         2.1484          INLAND
# 20375      1527.0       507.0         8.4443       <1H OCEAN
# 19318       524.0       259.0         2.0556      NEAR OCEAN
# ...           ...         ...            ...             ...
# 12820      1062.0       304.0         2.3438          INLAND
# 954         512.0       208.0         5.1406          INLAND
# 4531       1844.0       477.0         1.9405       <1H OCEAN
# 10390      1185.0       446.0         4.3542       <1H OCEAN
# 12304       158.0        39.0         3.4167          INLAND
#
#        median_house_value
# 12893            198500.0
# 19585             81800.0
# 9541              81300.0
# 20375            358500.0
# 19318            120000.0
# ...                   ...
# 12820             89400.0
# 954              315600.0
# 4531             152500.0
# 10390            195600.0
# 12304            100000.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
correlation_matrix = train_data.select_dtypes(include=["float","int"]).corr()

# %%
correlation_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924770           -0.106293     0.044108
# latitude            -0.924770  1.000000            0.009185    -0.034133
# housing_median_age  -0.106293  0.009185            1.000000    -0.359433
# total_rooms          0.044108 -0.034133           -0.359433     1.000000
# total_bedrooms       0.067552 -0.063863           -0.319320     0.930589
# population           0.096094 -0.103885           -0.293208     0.854405
# households           0.053651 -0.067431           -0.301601     0.917785
# median_income       -0.019796 -0.074863           -0.117274     0.197419
# median_house_value  -0.047996 -0.141600            0.110408     0.130695
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.067552    0.096094    0.053651      -0.019796
# latitude                 -0.063863   -0.103885   -0.067431      -0.074863
# housing_median_age       -0.319320   -0.293208   -0.301601      -0.117274
# total_rooms               0.930589    0.854405    0.917785       0.197419
# total_bedrooms            1.000000    0.873257    0.978702      -0.008555
# population                0.873257    1.000000    0.903596       0.005709
# households                0.978702    0.903596    1.000000       0.012314
# median_income            -0.008555    0.005709    0.012314       1.000000
# median_house_value        0.046407   -0.025287    0.062582       0.688724
#
#                     median_house_value
# longitude                    -0.047996
# latitude                     -0.141600
# housing_median_age            0.110408
# total_rooms                   0.130695
# total_bedrooms                0.046407
# population                   -0.025287
# households                    0.062582
# median_income                 0.688724
# median_house_value            1.000000

# %%
correlation_matrix.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.984163           -0.182160     0.137804
# latitude            -0.984163  1.000000            0.107518    -0.095834
# housing_median_age  -0.182160  0.107518            1.000000    -0.805547
# total_rooms          0.137804 -0.095834           -0.805547     1.000000
# total_bedrooms       0.162189 -0.110274           -0.754846     0.987038
# population           0.199415 -0.144687           -0.745037     0.976156
# households           0.156958 -0.108308           -0.749331     0.987363
# median_income       -0.007933 -0.107302           -0.121295    -0.094437
# median_house_value  -0.009137 -0.146638            0.114084    -0.195265
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.162189    0.199415    0.156958      -0.007933
# latitude                 -0.110274   -0.144687   -0.108308      -0.107302
# housing_median_age       -0.754846   -0.745037   -0.749331      -0.121295
# total_rooms               0.987038    0.976156    0.987363      -0.094437
# total_bedrooms            1.000000    0.989897    0.999394      -0.236683
# population                0.989897    1.000000    0.991930      -0.252232
# households                0.999394    0.991930    1.000000      -0.226958
# median_income            -0.236683   -0.252232   -0.226958       1.000000
# median_house_value       -0.298600   -0.332192   -0.287609       0.891208
#
#                     median_house_value
# longitude                    -0.009137
# latitude                     -0.146638
# housing_median_age            0.114084
# total_rooms                  -0.195265
# total_bedrooms               -0.298600
# population                   -0.332192
# households                   -0.287609
# median_income                 0.891208
# median_house_value            1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix.corr(),annot = True)
# Out:
# <Axes: >

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] +1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] +1)
train_data["population"] = np.log(train_data["population"] +1)
train_data["households"] = np.log(train_data["households"] +1)

#for normalization

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7185
# INLAND        5190
# NEAR OCEAN    2161
# NEAR BAY      1806
# ISLAND           4
# Name: count, dtype: int64

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(["ocean_proximity"],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12893    -121.33     38.65                23.0     7.802618        6.261492
# 19585    -120.69     37.59                27.0     7.065613        5.429346
# 9541     -120.74     37.33                30.0     7.779467        6.154858
# 20375    -118.84     34.15                17.0     8.239065        6.204558
# 19318    -123.02     38.46                52.0     7.675546        6.214608
# ...          ...       ...                 ...          ...             ...
# 12820    -121.48     38.61                18.0     7.321189        5.755742
# 954      -121.92     37.64                46.0     7.155396        5.347108
# 4531     -118.21     34.04                43.0     7.315218        6.169611
# 10390    -117.65     33.57                 5.0     7.600402        6.216606
# 12304    -116.80     33.80                35.0     5.783825        4.158883
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 12893    7.032624    6.242223         2.6266            198500.0      False
# 19585    6.493754    5.407172         2.3906             81800.0      False
# 9541     7.251345    6.061457         2.1484             81300.0      False
# 20375    7.331715    6.230481         8.4443            358500.0       True
# 19318    6.263398    5.560682         2.0556            120000.0      False
# ...           ...         ...            ...                 ...        ...
# 12820    6.968850    5.720312         2.3438             89400.0      False
# 954      6.240276    5.342334         5.1406            315600.0      False
# 4531     7.520235    6.169611         1.9405            152500.0       True
# 10390    7.078342    6.102559         4.3542            195600.0       True
# 12304    5.068904    3.688879         3.4167            100000.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 12893    True   False     False       False
# 19585    True   False     False       False
# 9541     True   False     False       False
# 20375   False   False     False       False
# 19318   False   False     False        True
# ...       ...     ...       ...         ...
# 12820    True   False     False       False
# 954      True   False     False       False
# 4531    False   False     False       False
# 10390   False   False     False       False
# 12304    True   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(train_data.corr(),annot = True,)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]
train_data["household_rooms"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

x_train, y_train =train_data.drop(["median_house_value"],axis = 1),train_data["median_house_value"]

#x_train = train_data.drop(["median_house_value"], axis=1)
#y_train = train_data["median_house_value"]

reg = LinearRegression()

reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

test_data["total_rooms"] = np.log(test_data["total_rooms"] +1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] +1)
test_data["population"] = np.log(test_data["population"] +1)
test_data["households"] = np.log(test_data["households"] +1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(["ocean_proximity"],axis=1)

test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data["household_rooms"] = test_data["total_rooms"] / test_data["households"]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4265     -118.32     34.10                28.0     7.473069        6.575076
# 19949    -119.37     36.21                35.0     7.709308        6.167516
# 5376     -118.39     34.04                52.0     7.308543        5.627621
# 9618     -120.46     37.29                30.0     7.997327        6.455199
# 9882     -121.79     36.68                22.0     8.841159        7.322510
# ...          ...       ...                 ...          ...             ...
# 15950    -122.44     37.72                49.0     7.351158        6.006353
# 12219    -117.27     33.55                 4.0     8.718173        6.792344
# 8703     -118.34     33.84                36.0     7.353722        5.533389
# 15373    -117.25     33.38                17.0     7.387090        6.068426
# 1118     -121.57     39.80                23.0     6.673298        4.927254
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 4265     7.288928    6.431331         1.7306            450000.0       True
# 19949    7.357556    6.109248         1.4455             54100.0      False
# 5376     6.502790    5.669881         4.7386            340400.0       True
# 9618     7.570959    6.381816         2.3594             72300.0      False
# 9882     8.241440    7.283448         3.0608            168300.0       True
# ...           ...         ...            ...                 ...        ...
# 15950    7.068172    5.955837         3.4605            265000.0      False
# 12219    7.644441    6.569481         5.5351            429000.0       True
# 8703     6.608001    5.537334         6.2778            309700.0       True
# 15373    6.939254    5.966147         2.0956            134400.0       True
# 1118     5.902633    5.030438         2.1912            115200.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 4265    False   False     False       False       0.879836         1.161979
# 19949    True   False     False       False       0.800009         1.261908
# 5376    False   False     False       False       0.770006         1.289012
# 9618     True   False     False       False       0.807170         1.253143
# 9882    False   False     False       False       0.828230         1.213870
# ...       ...     ...       ...         ...            ...              ...
# 15950   False   False      True       False       0.817062         1.234278
# 12219   False   False     False       False       0.779102         1.327072
# 8703    False   False     False       False       0.752461         1.328026
# 15373   False   False     False       False       0.821491         1.238168
# 1118     True   False     False       False       0.738354         1.326584
#
# [4087 rows x 16 columns]

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 
0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 12893    True   False     False       False       0.802486         1.249974
# 19585    True   False     False       False       0.768418         1.306711
# 9541     True   False     False       False       0.791167         1.283432
# 20375   False   False     False       False       0.753066         1.322380
# 19318   False   False     False        True       0.809663         1.380325
# ...       ...     ...       ...         ...            ...              ...
# 12820    True   False     False       False       0.786176         1.279858
# 954      True   False     False       False       0.747283         1.339376
# 4531    False   False     False       False       0.843394         1.185686
# 10390   False   False     False       False       0.817931         1.245445
# 12304    True   False     False       False       0.719054         1.567908
#
# [16346 rows x 16 columns]

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4265     -118.32     34.10                28.0     7.473069        6.575076
# 19949    -119.37     36.21                35.0     7.709308        6.167516
# 5376     -118.39     34.04                52.0     7.308543        5.627621
# 9618     -120.46     37.29                30.0     7.997327        6.455199
# 9882     -121.79     36.68                22.0     8.841159        7.322510
# ...          ...       ...                 ...          ...             ...
# 15950    -122.44     37.72                49.0     7.351158        6.006353
# 12219    -117.27     33.55                 4.0     8.718173        6.792344
# 8703     -118.34     33.84                36.0     7.353722        5.533389
# 15373    -117.25     33.38                17.0     7.387090        6.068426
# 1118     -121.57     39.80                23.0     6.673298        4.927254
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 4265     7.288928    6.431331         1.7306       True   False   False
# 19949    7.357556    6.109248         1.4455      False    True   False
# 5376     6.502790    5.669881         4.7386       True   False   False
# 9618     7.570959    6.381816         2.3594      False    True   False
# 9882     8.241440    7.283448         3.0608       True   False   False
# ...           ...         ...            ...        ...     ...     ...
# 15950    7.068172    5.955837         3.4605      False   False   False
# 12219    7.644441    6.569481         5.5351       True   False   False
# 8703     6.608001    5.537334         6.2778       True   False   False
# 15373    6.939254    5.966147         2.0956       True   False   False
# 1118     5.902633    5.030438         2.1912      False    True   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 4265      False       False       0.879836         1.161979
# 19949     False       False       0.800009         1.261908
# 5376      False       False       0.770006         1.289012
# 9618      False       False       0.807170         1.253143
# 9882      False       False       0.828230         1.213870
# ...         ...         ...            ...              ...
# 15950      True       False       0.817062         1.234278
# 12219     False       False       0.779102         1.327072
# 8703      False       False       0.752461         1.328026
# 15373     False       False       0.821491         1.238168
# 1118      False       False       0.738354         1.326584
#
# [4087 rows x 15 columns]

# %%
y_test
# Out:
# 4265     450000.0
# 19949     54100.0
# 5376     340400.0
# 9618      72300.0
# 9882     168300.0
#            ...
# 15950    265000.0
# 12219    429000.0
# 8703     309700.0
# 15373    134400.0
# 1118     115200.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
reg.score(x_test,y_test)
# Out:
# 0.6745680248576671

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.8209142853293196

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.8172408526769686

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators":[100,200,300],
    "max_features":[2,4,6,8]
    
}
grid_search = GridSearchCV(forest,param_grid,cv=5,scoring="neg_mean_squared_error",return_train_score=True)

grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [2, 4, 6, 8],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(x_test,y_test)
# Out:
# 0.8219870417271018
